# %%
import pandas as pd

# %%
df = pd.read_csv('vehicle_safety_info.csv')
types = pd.read_csv('models.csv')

# %%
stars = pd.Series(df.columns[df.columns.str.contains('STAR')])
nhtsa = pd.Series(df.columns[df.columns.str.contains('NHTSA')])
other_cols = pd.Series(['MODEL_YR', 'MAKE', 'MODEL', 'MMY', 'VEHICLE_ID'])
cols_to_keep = pd.concat([other_cols, stars, nhtsa])

df = df[cols_to_keep]

# %%
df = pd.merge(df, types, on = 'MODEL')

# %%
df = df[(df.OVERALL_FRNT_STARS != 'Not Rated') & (df.OVERALL_STARS != 'Not Rated')]

# %%
brands_to_keep = ['ACURA', 'AUDI', 'BMW', 'FORD', 'GENESIS', 'HONDA', 'HYUNDAI', 'INFINITI', 'MAZDA', 'MERCEDES-BENZ', 'MINI', 'NISSAN', 'PORSCHE','SUBARU', 'TESLA', 'VOLSWAGEN', 'VOLVO']
types_to_keep = ['SUV', 'HATCH']

# %%
filter_df = df[(df.MAKE.isin(brands_to_keep)) & df.TYPE.isin(types_to_keep)]

def cleaner(x):
    x = pd.to_numeric(x, errors = 'ignore')
    return x
    
filter_df = filter_df.apply(cleaner, 0)

min_stars = 5

# CONSOLIDATE VEHICLES WHERE RATINGS ARE IDENTICAL ACROSS TRIMS
cols = filter_df.columns.drop(['VEHICLE_ID', 'MMY'])
filter_df = filter_df[cols].drop_duplicates()

# DETERMINE VEHICLES THAT DON'T MEET SAFETY CRITERIA
ruled_out = filter_df[filter_df.OVERALL_STARS < min_stars]
print 'RULING OUT:'
print ruled_out[['MAKE', 'MODEL']]

filter_df = filter_df[filter_df.OVERALL_STARS >= min_stars]
# Out:
# RULING OUT:
#         MAKE   MODEL
# 60      AUDI      Q5
# 85      AUDI     SQ5
# 899    MAZDA    CX-5
# 901    MAZDA    CX-5
# 1048  NISSAN   ROGUE
# 1050  NISSAN   ROGUE
# 1472  NISSAN  MURANO

# %%
filter_df
# Out:
#       MODEL_YR      MAKE           MODEL  OVERALL_STARS  OVERALL_FRNT_STARS  \
# 2         2018     ACURA             MDX              5                   5
# 4         2017     ACURA             MDX              5                   5
# 8         2018     ACURA             RDX              5                   5
# 10        2017     ACURA             RDX              5                   5
# 61        2018      AUDI              Q7              5                   4
# 195       2018       BMW              X5              5                   5
# 197       2017       BMW              X5              5                   5
# 420       2018      FORD            EDGE              5                   5
# 422       2017      FORD            EDGE              5                   5
# 424       2018      FORD          ESCAPE              5                   5
# 426       2017      FORD          ESCAPE              5                   5
# 430       2017      FORD      EXPEDITION              5                   5
# 431       2017      FORD      EXPEDITION              5                   5
# 434       2017      FORD   EXPEDITION EL              5                   5
# 435       2017      FORD   EXPEDITION EL              5                   5
# 436       2018      FORD        EXPLORER              5                   5
# 438       2017      FORD        EXPLORER              5                   5
# 619       2018     HONDA            CR-V              5                   5
# 621       2017     HONDA            CR-V              5                   5
# 625       2018     HONDA            HR-V              5                   4
# 627       2017     HONDA            HR-V              5                   4
# 631       2018     HONDA           PILOT              5                   4
# 633       2017     HONDA           PILOT              5                   4
# 653       2018   HYUNDAI        SANTA FE              5                   4
# 657       2018   HYUNDAI  SANTA FE SPORT              5                   5
# 659       2017   HYUNDAI  SANTA FE SPORT              5                   5
# 667       2018   HYUNDAI          TUCSON              5                   5
# 669       2017   HYUNDAI          TUCSON              5                   5
# 697       2018  INFINITI            QX60              5                   4
# 699       2017  INFINITI            QX60              5                   4
# 895       2018     MAZDA            CX-3              5                   5
# 897       2017     MAZDA            CX-3              5                   5
# 1044      2018    NISSAN      PATHFINDER              5                   4
# 1046      2017    NISSAN      PATHFINDER              5                   4
# 1213      2018    SUBARU       CROSSTREK              5                   4
# 1214      2017    SUBARU       CROSSTREK              5                   4
# 1215      2018    SUBARU        FORESTER              5                   4
# 1216      2017    SUBARU        FORESTER              5                   4
# 1223      2018    SUBARU         OUTBACK              5                   5
# 1224      2017    SUBARU         OUTBACK              5                   5
# 1363      2018     VOLVO         XC90 T5              5                   5
# 1365      2017     VOLVO         XC90 T5              5                   5
# 1367      2018     VOLVO         XC90 T6              5                   5
# 1369      2017     VOLVO         XC90 T6              5                   5
# 1371      2018     VOLVO         XC90 T8              5                   5
# 1372      2017     VOLVO         XC90 T8              5                   5
# 1380      2017       BMW              X3              5                   5
# 1429      2017  INFINITI     QX60 HYBRID              5                   4
# 1471      2017    NISSAN          MURANO              5                   4
# 1508      2017     VOLVO            XC60              5                   5
#
#       FRNT_DRIV_STARS  FRNT_PASS_STARS  OVERALL_SIDE_STARS  SIDE_DRIV_STARS  \
# 2                   5                5                   5                5
# 4                   5                5                   5                5
# 8                   5                5                   5                5
# 10                  5                5                   5                5
# 61                  4                4                   5                5
# 195                 5                5                   5                5
# 197                 5                5                   5                5
# 420                 5                5                   5                5
# 422                 5                5                   5                5
# 424                 5                4                   5                5
# 426                 5                4                   5                5
# 430                 5                5                   5                5
# 431                 5                5                   5                5
# 434                 5                5                   5                5
# 435                 5                5                   5                5
# 436                 4                5                   5                5
# 438                 4                5                   5                5
# 619                 5                5                   5                5
# 621                 5                5                   5                5
# 625                 4                4                   5                5
# 627                 4                4                   5                5
# 631                 5                4                   5                5
# 633                 5                4                   5                5
# 653                 4                4                   5                5
# 657                 5                4                   5                5
# 659                 5                4                   5                5
# 667                 5                5                   5                5
# 669                 5                5                   5                5
# 697                 4                5                   5                5
# 699                 4                5                   5                5
# 895                 5                5                   5                5
# 897                 5                5                   5                5
# 1044                4                5                   5                5
# 1046                4                5                   5                5
# 1213                4                4                   5                5
# 1214                4                4                   5                5
# 1215                5                4                   5                5
# 1216                5                4                   5                5
# 1223                5                5                   5                5
# 1224                5                5                   5                5
# 1363                5                5                   5                5
# 1365                5                5                   5                5
# 1367                5                5                   5                5
# 1369                5                5                   5                5
# 1371                5                5                   5                5
# 1372                5                5                   5                5
# 1380                5                4                   5                5
# 1429                4                5                   5                5
# 1471                4                4                   5                5
# 1508                5                5                   5                5
#
#       SIDE_PASS_STARS  ROLLOVER_STARS ROLLOVER_STARS_2  SIDE_POLE_STARS  \
# 2                   5               4        Not Rated                5
# 4                   5               4        Not Rated                5
# 8                   5               4        Not Rated                5
# 10                  5               4        Not Rated                5
# 61                  5               4        Not Rated                5
# 195                 5               4        Not Rated                5
# 197                 5               4        Not Rated                5
# 420                 5               4        Not Rated                5
# 422                 5               4        Not Rated                5
# 424                 5               4        Not Rated                5
# 426                 5               4        Not Rated                5
# 430                 5               3        Not Rated                5
# 431                 5               4        Not Rated                5
# 434                 5               3        Not Rated                5
# 435                 5               4        Not Rated                5
# 436                 5               4        Not Rated                5
# 438                 5               4        Not Rated                5
# 619                 5               4        Not Rated                5
# 621                 5               4        Not Rated                5
# 625                 5               4        Not Rated                5
# 627                 5               4        Not Rated                5
# 631                 5               4        Not Rated                5
# 633                 5               4        Not Rated                5
# 653                 5               4        Not Rated                5
# 657                 5               4        Not Rated                5
# 659                 5               4        Not Rated                5
# 667                 5               4        Not Rated                4
# 669                 5               4        Not Rated                4
# 697                 5               4        Not Rated                5
# 699                 5               4        Not Rated                5
# 895                 5               4        Not Rated                5
# 897                 5               4        Not Rated                5
# 1044                5               4        Not Rated                5
# 1046                5               4        Not Rated                5
# 1213                5               4        Not Rated                5
# 1214                5               4        Not Rated                4
# 1215                5               4        Not Rated                5
# 1216                5               4        Not Rated                5
# 1223                5               4        Not Rated                5
# 1224                5               4        Not Rated                5
# 1363                5               4        Not Rated                5
# 1365                5               4        Not Rated                5
# 1367                5               4        Not Rated                5
# 1369                5               4        Not Rated                5
# 1371                5               4        Not Rated                5
# 1372                5               4        Not Rated                5
# 1380                5               4        Not Rated                5
# 1429                5               4        Not Rated                5
# 1471                5               4        Not Rated                5
# 1508                5               4        Not Rated                5
#
#      NHTSA_ESC NHTSA_FRNT_COLLISION_WARNING NHTSA_LANE_DEPARTURE_WARNING  \
# 2          NaN                     Standard                     Standard
# 4          NaN                     Standard                     Standard
# 8          NaN                     Optional                     Optional
# 10         NaN                     Optional                     Optional
# 61         NaN                     Standard                     Optional
# 195        NaN                     Optional                     Optional
# 197        NaN                          NaN                          NaN
# 420        NaN                     Optional                     Optional
# 422        NaN                     Optional                     Optional
# 424        NaN                     Optional                     Optional
# 426        NaN                     Optional                     Optional
# 430        NaN                          NaN                          NaN
# 431        NaN                          NaN                          NaN
# 434        NaN                          NaN                          NaN
# 435        NaN                          NaN                          NaN
# 436        NaN                     Optional                     Optional
